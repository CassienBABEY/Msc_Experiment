# %%
import pandas as pd
import numpy as np

# %%
CJ1 = pd.read_csv("data_expe/CJ1_data.csv")
CJ1
# Out:
#                                             anecdotes fichier  \
# 0                                                 NaN     NaN
# 1   Seulement 2 pays touchent 3 océans, les Etats-...   FAITS
# 2   L’œil d’une autruche est plus gros que son cer...   ITEMS
# 3   Les frites sont originaires de France et non d...   INFOS
# 4   La cacahuète est l’un des ingrédients de la dy...  POINTS
# ..                                                ...     ...
# 63  L’indicatif téléphonique international de l’An...   INFOS
# 64  L’écriture chinoise comprend plus de 40 000 ca...    NOMS
# 65  Une personne brule plus de calories quand il d...   ITEMS
# 66  La cacahuète est l’un des ingrédients de la dy...  POINTS
# 67                                                NaN     NaN
#
#                                        anecdotes_reco  boucle_tâche.thisRepN  \
# 0                                                 NaN                    NaN
# ...

# %%
CJ1.columns
# Out:
# Index(['anecdotes', 'fichier', 'anecdotes_reco', 'boucle_tâche.thisRepN',
#        'boucle_tâche.thisTrialN', 'boucle_tâche.thisN',
#        'boucle_tâche.thisIndex', 'boucle_reco.thisRepN',
#        'boucle_reco.thisTrialN', 'boucle_reco.thisN', 'boucle_reco.thisIndex',
#        'textWelcome.started', 'Instructions.started', 'textWelcome.stopped',
#        'key_resp.started', 'key_resp.keys', 'key_resp.rt', 'Anecdotes.started',
#        'tache_text.started', 'Validation_button.started',
#        'mouse_click.started', 'tache_text.text', 'mouse_click.x',
#        'mouse_click.y', 'mouse_click.leftButton', 'mouse_click.midButton',
#        'mouse_click.rightButton', 'mouse_click.time',
#        'mouse_click.clicked_name', 'feedbacktext.started',
#        'feedback_fichier_train.started', 'feedbacktext.stopped',
#        'feedback_fichier_train.stopped', 'text.started', 'text.stopped',
#        'waiting_screen.started', 'key_resp_2.started', 'key_resp_2.keys',
# ...

# %%
CJ1 = CJ1[['anecdotes','fichier','tache_text.text','anecdotes_reco','reco_text.text']]

# %%
CJ1_Tâche1 = CJ1[['anecdotes','tache_text.text','fichier']].loc[1:32]
CJ1_Tâche1
# Out:
#                                             anecdotes  \
# 1   Seulement 2 pays touchent 3 océans, les Etats-...
# 2   L’œil d’une autruche est plus gros que son cer...
# 3   Les frites sont originaires de France et non d...
# 4   La cacahuète est l’un des ingrédients de la dy...
# 5                   Il y a eu 25 présidents Français
# 6   L’écriture chinoise comprend plus de 40 000 ca...
# 7   Tout comme l’empreinte digitale, le cœur est p...
# 8           Le cœur d’une crevette est dans sa tête
# 9   On peut reproduire une clé grâce au son qu’ell...
# 10  La plus longue composition classique prendrait...
# 11  La navette Spatiale Columbia s’est désintégrée...
# 12  Un attentat terroriste a eu lieu dans les métr...
# 13  Le tsunami dévastateur en Asie s’est produit e...
# 14  Une personne brule plus de calories quand il d...
# 15  La raie manta peut atteindre 9 mètres de long ...
# 16  L’indicatif téléphonique international de l’An...
# ...

# %%
CJ1_RECO = CJ1[['anecdotes_reco','fichier','reco_text.text']].loc[35:66]
CJ1_RECO = CJ1_RECO.reset_index()
CJ1_RECO['reco_text.text'] = CJ1_RECO['reco_text.text'].str.upper()
CJ1_RECO['reco_text.text'] = CJ1_RECO['reco_text.text'].replace(
    'DONNÉES',
    'DONNEES').replace('FAIT', 'FAITS').replace('DONNEE', 'DONNEES').replace(
        'POINT',
        'POINTS').replace('ITEM', 'ITEMS').replace('NOM', 'NOMS').replace(
            'INFO', 'INFOS').replace('DONNÉE',
                                     'DONNEES').replace('DONNÉS', 'DONNEES').replace('DONNÉ','DONNEES')
CJ1_RECO
# Out:
#     index                                     anecdotes_reco  fichier  \
# 0      35  Il y a en moyenne 178 graines de sésames sur l...     NOMS
# 1      36  Les oiseaux bleus ne peuvent pas voir la coule...    FAITS
# 2      37  La raie manta peut atteindre 9 mètres de long ...    INFOS
# 3      38  Les élastiques sont plus longs quand ils sont ...    INFOS
# 4      39                  Il y a eu 25 présidents Français   DONNEES
# 5      40  On peut reproduire une clé grâce au son qu’ell...   POINTS
# 6      41  Le tsunami dévastateur en Asie s’est produit e...    FAITS
# 7      42  Une vache produit environ 200 000 bouteilles d...    FAITS
# 8      43             Les ongles incarnés sont héréditaires   DONNEES
# 9      44  Tout comme l’empreinte digitale, le cœur est p...     NOMS
# 10     45  L’Himalaya continue de grandir en raison des c...    ITEMS
# 11     46  Une personne perdra environ 18 kilos de peau d...   POINTS
# ...

# %%
Grep = CJ1_RECO['fichier']==CJ1_RECO['reco_text.text']

# %%
Grep
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# dtype: bool

# %%
Grep.value_counts()
# Out:
# False    23
# True      9
# dtype: int64
